# %% [markdown]
# # Notes on this
# Learn the application of contours and the density plots and then start using them

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style("whitegrid")

# %% [markdown]
# They are used for plotting 3D data on 2D

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)

# %%
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, color='black')
# Out:
# /var/folders/kw/36zx74vs4rdc61z3sl65cnym0000gn/T/ipykernel_9641/1494646523.py:1: UserWarning: The following kwargs were not used by contour: 'color'
#   plt.contour(X, Y, Z, color='black')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style("whitegrid")

# %%
data = np.random.randn(1000)

# %%
plt.hist(data, bins=30, density=True, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([0.00595905, 0.        , 0.00595905, 0.        , 0.00893858,
#         0.00595905, 0.01489763, 0.02979525, 0.0476724 , 0.05363145,
#         0.05661098, 0.05661098, 0.07746765, 0.09236528, 0.13109911,
#         0.11918101, 0.19068961, 0.21452581, 0.20260771, 0.17281246,
#         0.16089436, 0.19962819, 0.18473056, 0.16685341, 0.14003768,
#         0.14003768, 0.12514006, 0.0953448 , 0.07448813, 0.04469288,
#         0.0595905 , 0.0238362 , 0.02979525, 0.01787715, 0.01489763,
#         0.00297953, 0.00893858, 0.        , 0.        , 0.00297953]),
#  array([-3.72241452, -3.38679057, -3.05116662, -2.71554267, -2.37991872,
#         -2.04429477, -1.70867082, -1.37304687, -1.03742292, -0.70179897,
#         -0.36617502, -0.03055107,  0.30507288,  0.64069683,  0.97632078,
#          1.31194473,  1.64756868,  1.98319263,  2.31881658,  2.65444053,
#          2.99006448,  3.32568843,  3.66131238,  3.99693633,  4.33256028,
#          4.66818423,  5.00380818,  5.33943213,  5.67505608,  6.01068003,
#          6.34630398,  6.68192793,  7.01755187,  7.35317582,  7.68879977,
#          8.02442372,  8.36004767,  8.69567162,  9.03129557,  9.36691952,
#          9.70254347]),
#  [<matplotlib.patches.Polygon at 0x31bea2c50>])

# %% [markdown]
# ## 2D histogram

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')
